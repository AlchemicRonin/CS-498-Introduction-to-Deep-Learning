# %% [markdown]
# <a href="https://colab.research.google.com/github/AlchemicRonin/CS-498-Introduction-to-Deep-Learning/blob/TY/neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS498DL Assignment 2

# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount= True)

import os
os.chdir("/content/drive/My Drive/assignment2")
# Out:
# Mounted at /content/drive/

# %%
import matplotlib.pyplot as plt
import numpy as np

from kaggle_submission import output_submission_csv
from models.neural_net import NeuralNetwork
from utils.data_process import get_CIFAR10_data

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)  # set default size of plots

# For auto-reloading external modules
# See http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Loading CIFAR-10
# Now that you have implemented a neural network that passes gradient checks and works on toy data, you will test your network on the CIFAR-10 dataset.

# %%
# You can change these numbers for experimentation
# For submission be sure they are set to the default values
TRAIN_IMAGES = 49000
VAL_IMAGES = 1000
TEST_IMAGES = 10000

data = get_CIFAR10_data(TRAIN_IMAGES, VAL_IMAGES, TEST_IMAGES)
X_train, y_train = data['X_train'], data['y_train']
X_val, y_val = data['X_val'], data['y_val']
X_test, y_test = data['X_test'], data['y_test']

# %% [markdown]
# ## Train using SGD
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.
#
# You can try different numbers of layers and other hyperparameters on the CIFAR-10 dataset below.

# %%
# Hyperparameters
input_size = 32 * 32 * 3
num_layers = 3
hidden_size = 240
hidden_sizes = [hidden_size] * (num_layers - 1)
num_classes = 10
epochs = 400
batch_size = 200
learning_rate = 1e-1
learning_rate_decay = 0.95
regularization = 0.0001

# Initialize a new neural network model
net = NeuralNetwork(input_size, hidden_sizes, num_classes, num_layers)

# Variables to store performance for each epoch
train_loss_SGD = np.zeros(epochs)
train_accuracy_SGD = np.zeros(epochs)
validation_SGD = np.zeros(epochs)

# For each epoch...
for epoch in range(epochs):
    # Training
    # For each mini-batch...
    #rate = learning_rate
    rate = learning_rate*(learning_rate_decay ** (epoch//10))
    print("Learning Rate: %.5f" %(rate))
    batch_index= np.random.choice(TRAIN_IMAGES, batch_size, replace=False)
    X_batch = X_train[batch_index]
    y_batch = y_train[batch_index]
    # Run the forward pass of the model to get a prediction and compute the accuracy
    # Run the backward pass of the model to update the weights and compute the loss
    train_loss_SGD[epoch] = net.backward(X_train,y_train, rate, regularization)
    train_accuracy_SGD[epoch] = (np.argmax(net.outputs["L1"+ str(num_layers)],axis = 1) == y_train).mean()
    # Validation
    # No need to run the backward pass here, just run the forward pass to compute accuracy
    validation_SGD[epoch] = (np.argmax(net.forward(X_val),axis = 1) == y_val).mean()
    print("Epoch %4d, Train Loss: %4.3f, Train Accuracy: %3.1f%%, Valid: %3.1f%%" %(epoch + 1, train_loss_SGD[epoch], train_accuracy_SGD[epoch] * 100, validation_SGD[epoch] * 100))
# Out:
# Learning Rate: 0.10000
# Epoch    1, Train Loss: 2.507, Train Accuracy: 9.5%, Valid: 15.6%
# Learning Rate: 0.10000
# Epoch    2, Train Loss: 2.259, Train Accuracy: 18.5%, Valid: 20.9%
# Learning Rate: 0.10000
# Epoch    3, Train Loss: 2.178, Train Accuracy: 23.0%, Valid: 24.4%
# Learning Rate: 0.10000
# Epoch    4, Train Loss: 2.122, Train Accuracy: 25.4%, Valid: 28.2%
# Learning Rate: 0.10000
# Epoch    5, Train Loss: 2.080, Train Accuracy: 27.7%, Valid: 29.0%
# Learning Rate: 0.10000
# Epoch    6, Train Loss: 2.045, Train Accuracy: 29.2%, Valid: 31.5%
# Learning Rate: 0.10000
# Epoch    7, Train Loss: 2.016, Train Accuracy: 30.6%, Valid: 31.6%
# Learning Rate: 0.10000
# Epoch    8, Train Loss: 1.991, Train Accuracy: 31.7%, Valid: 32.9%
# Learning Rate: 0.10000
# Epoch    9, Train Loss: 1.969, Train Accuracy: 32.8%, Valid: 33.3%
# Learning Rate: 0.10000
# Epoch   10, Train Loss: 1.950, Train Accuracy: 33.5%, Valid: 33.8%
# Learning Rate: 0.09500
# Epoch   11, Train Loss: 1.932, Train Accuracy: 34.3%, Valid: 34.1%
# Learning Rate: 0.09500
# Epoch   12, Train Loss: 1.916, Train Accuracy: 34.9%, Valid: 34.6%
# Learning Rate: 0.09500
# Epoch   13, Train Loss: 1.902, Train Accuracy: 35.5%, Valid: 35.1%
# Learning Rate: 0.09500
# Epoch   14, Train Loss: 1.889, Train Accuracy: 35.9%, Valid: 35.7%
# Learning Rate: 0.09500
# Epoch   15, Train Loss: 1.877, Train Accuracy: 36.4%, Valid: 36.0%
# Learning Rate: 0.09500
# Epoch   16, Train Loss: 1.865, Train Accuracy: 36.8%, Valid: 36.3%
# Learning Rate: 0.09500
# Epoch   17, Train Loss: 1.855, Train Accuracy: 37.1%, Valid: 36.7%
# Learning Rate: 0.09500
# Epoch   18, Train Loss: 1.844, Train Accuracy: 37.4%, Valid: 37.0%
# Learning Rate: 0.09500
# Epoch   19, Train Loss: 1.835, Train Accuracy: 37.9%, Valid: 37.1%
# Learning Rate: 0.09500
# Epoch   20, Train Loss: 1.826, Train Accuracy: 38.1%, Valid: 37.8%
# Learning Rate: 0.09025
# Epoch   21, Train Loss: 1.818, Train Accuracy: 38.5%, Valid: 37.8%
# Learning Rate: 0.09025
# Epoch   22, Train Loss: 1.811, Train Accuracy: 38.7%, Valid: 38.0%
# Learning Rate: 0.09025
# Epoch   23, Train Loss: 1.804, Train Accuracy: 39.0%, Valid: 38.8%
# Learning Rate: 0.09025
# Epoch   24, Train Loss: 1.797, Train Accuracy: 39.1%, Valid: 38.5%
# Learning Rate: 0.09025
# Epoch   25, Train Loss: 1.791, Train Accuracy: 39.3%, Valid: 39.2%
# Learning Rate: 0.09025
# Epoch   26, Train Loss: 1.786, Train Accuracy: 39.4%, Valid: 38.8%
# Learning Rate: 0.09025
# Epoch   27, Train Loss: 1.781, Train Accuracy: 39.5%, Valid: 39.7%
# Learning Rate: 0.09025
# Epoch   28, Train Loss: 1.776, Train Accuracy: 39.7%, Valid: 38.3%
# Learning Rate: 0.09025
# Epoch   29, Train Loss: 1.773, Train Accuracy: 39.7%, Valid: 40.3%
# Learning Rate: 0.09025
# Epoch   30, Train Loss: 1.768, Train Accuracy: 40.0%, Valid: 38.4%
# Learning Rate: 0.08574
# Epoch   31, Train Loss: 1.766, Train Accuracy: 39.9%, Valid: 41.1%
# Learning Rate: 0.08574
# Epoch   32, Train Loss: 1.758, Train Accuracy: 40.3%, Valid: 38.8%
# Learning Rate: 0.08574
# Epoch   33, Train Loss: 1.755, Train Accuracy: 40.4%, Valid: 41.1%
# Learning Rate: 0.08574
# Epoch   34, Train Loss: 1.748, Train Accuracy: 40.6%, Valid: 38.6%
# Learning Rate: 0.08574
# Epoch   35, Train Loss: 1.746, Train Accuracy: 40.6%, Valid: 41.7%
# Learning Rate: 0.08574
# Epoch   36, Train Loss: 1.740, Train Accuracy: 41.0%, Valid: 38.9%
# Learning Rate: 0.08574
# Epoch   37, Train Loss: 1.738, Train Accuracy: 40.9%, Valid: 42.1%
# Learning Rate: 0.08574
# Epoch   38, Train Loss: 1.731, Train Accuracy: 41.3%, Valid: 39.2%
# Learning Rate: 0.08574
# Epoch   39, Train Loss: 1.728, Train Accuracy: 41.3%, Valid: 42.3%
# Learning Rate: 0.08574
# Epoch   40, Train Loss: 1.721, Train Accuracy: 41.7%, Valid: 39.6%
# Learning Rate: 0.08145
# Epoch   41, Train Loss: 1.718, Train Accuracy: 41.6%, Valid: 42.6%
# Learning Rate: 0.08145
# Epoch   42, Train Loss: 1.710, Train Accuracy: 42.2%, Valid: 40.8%
# Learning Rate: 0.08145
# Epoch   43, Train Loss: 1.706, Train Accuracy: 42.3%, Valid: 42.7%
# Learning Rate: 0.08145
# Epoch   44, Train Loss: 1.700, Train Accuracy: 42.5%, Valid: 40.7%
# Learning Rate: 0.08145
# Epoch   45, Train Loss: 1.696, Train Accuracy: 42.7%, Valid: 43.3%
# Learning Rate: 0.08145
# Epoch   46, Train Loss: 1.692, Train Accuracy: 42.9%, Valid: 40.9%
# Learning Rate: 0.08145
# Epoch   47, Train Loss: 1.688, Train Accuracy: 43.1%, Valid: 43.3%
# Learning Rate: 0.08145
# Epoch   48, Train Loss: 1.684, Train Accuracy: 43.2%, Valid: 40.5%
# Learning Rate: 0.08145
# Epoch   49, Train Loss: 1.681, Train Accuracy: 43.3%, Valid: 43.6%
# Learning Rate: 0.08145
# Epoch   50, Train Loss: 1.677, Train Accuracy: 43.5%, Valid: 40.9%
# Learning Rate: 0.07738
# Epoch   51, Train Loss: 1.674, Train Accuracy: 43.6%, Valid: 43.6%
# Learning Rate: 0.07738
# Epoch   52, Train Loss: 1.671, Train Accuracy: 43.7%, Valid: 41.3%
# Learning Rate: 0.07738
# Epoch   53, Train Loss: 1.667, Train Accuracy: 43.8%, Valid: 43.6%
# Learning Rate: 0.07738
# Epoch   54, Train Loss: 1.664, Train Accuracy: 43.9%, Valid: 41.8%
# Learning Rate: 0.07738
# Epoch   55, Train Loss: 1.661, Train Accuracy: 44.1%, Valid: 43.7%
# Learning Rate: 0.07738
# Epoch   56, Train Loss: 1.658, Train Accuracy: 44.2%, Valid: 42.2%
# Learning Rate: 0.07738
# Epoch   57, Train Loss: 1.656, Train Accuracy: 44.3%, Valid: 44.1%
# Learning Rate: 0.07738
# Epoch   58, Train Loss: 1.653, Train Accuracy: 44.4%, Valid: 42.6%
# Learning Rate: 0.07738
# Epoch   59, Train Loss: 1.650, Train Accuracy: 44.5%, Valid: 44.2%
# Learning Rate: 0.07738
# Epoch   60, Train Loss: 1.647, Train Accuracy: 44.6%, Valid: 42.5%
# Learning Rate: 0.07351
# Epoch   61, Train Loss: 1.645, Train Accuracy: 44.7%, Valid: 44.1%
# Learning Rate: 0.07351
# Epoch   62, Train Loss: 1.642, Train Accuracy: 44.7%, Valid: 43.0%
# Learning Rate: 0.07351
# Epoch   63, Train Loss: 1.640, Train Accuracy: 44.9%, Valid: 44.4%
# Learning Rate: 0.07351
# Epoch   64, Train Loss: 1.637, Train Accuracy: 44.9%, Valid: 43.6%
# Learning Rate: 0.07351
# Epoch   65, Train Loss: 1.635, Train Accuracy: 45.1%, Valid: 44.6%
# Learning Rate: 0.07351
# Epoch   66, Train Loss: 1.632, Train Accuracy: 45.1%, Valid: 43.4%
# Learning Rate: 0.07351
# Epoch   67, Train Loss: 1.630, Train Accuracy: 45.2%, Valid: 44.6%
# Learning Rate: 0.07351
# Epoch   68, Train Loss: 1.628, Train Accuracy: 45.3%, Valid: 43.8%
# Learning Rate: 0.07351
# Epoch   69, Train Loss: 1.626, Train Accuracy: 45.4%, Valid: 44.4%
# Learning Rate: 0.07351
# Epoch   70, Train Loss: 1.623, Train Accuracy: 45.4%, Valid: 43.8%
# Learning Rate: 0.06983
# Epoch   71, Train Loss: 1.621, Train Accuracy: 45.5%, Valid: 44.4%
# Learning Rate: 0.06983
# Epoch   72, Train Loss: 1.619, Train Accuracy: 45.5%, Valid: 44.3%
# Learning Rate: 0.06983
# Epoch   73, Train Loss: 1.617, Train Accuracy: 45.6%, Valid: 44.7%
# Learning Rate: 0.06983
# Epoch   74, Train Loss: 1.615, Train Accuracy: 45.7%, Valid: 44.4%
# Learning Rate: 0.06983
# Epoch   75, Train Loss: 1.613, Train Accuracy: 45.8%, Valid: 45.1%
# Learning Rate: 0.06983
# Epoch   76, Train Loss: 1.611, Train Accuracy: 45.8%, Valid: 44.5%
# Learning Rate: 0.06983
# Epoch   77, Train Loss: 1.609, Train Accuracy: 45.9%, Valid: 45.2%
# Learning Rate: 0.06983
# Epoch   78, Train Loss: 1.607, Train Accuracy: 45.9%, Valid: 44.6%
# Learning Rate: 0.06983
# Epoch   79, Train Loss: 1.605, Train Accuracy: 46.0%, Valid: 45.1%
# Learning Rate: 0.06983
# Epoch   80, Train Loss: 1.603, Train Accuracy: 46.1%, Valid: 44.7%
# Learning Rate: 0.06634
# Epoch   81, Train Loss: 1.601, Train Accuracy: 46.2%, Valid: 45.2%
# Learning Rate: 0.06634
# Epoch   82, Train Loss: 1.599, Train Accuracy: 46.2%, Valid: 44.8%
# Learning Rate: 0.06634
# Epoch   83, Train Loss: 1.597, Train Accuracy: 46.3%, Valid: 45.4%
# Learning Rate: 0.06634
# Epoch   84, Train Loss: 1.595, Train Accuracy: 46.3%, Valid: 44.7%
# Learning Rate: 0.06634
# Epoch   85, Train Loss: 1.594, Train Accuracy: 46.4%, Valid: 45.6%
# Learning Rate: 0.06634
# Epoch   86, Train Loss: 1.592, Train Accuracy: 46.5%, Valid: 44.8%
# Learning Rate: 0.06634
# Epoch   87, Train Loss: 1.590, Train Accuracy: 46.6%, Valid: 45.8%
# Learning Rate: 0.06634
# Epoch   88, Train Loss: 1.588, Train Accuracy: 46.6%, Valid: 45.0%
# Learning Rate: 0.06634
# Epoch   89, Train Loss: 1.587, Train Accuracy: 46.7%, Valid: 45.8%
# Learning Rate: 0.06634
# Epoch   90, Train Loss: 1.585, Train Accuracy: 46.7%, Valid: 45.0%
# Learning Rate: 0.06302
# Epoch   91, Train Loss: 1.583, Train Accuracy: 46.8%, Valid: 45.7%
, Valid: 47.7%
# Learning Rate: 0.04181
# Epoch  174, Train Loss: 1.493, Train Accuracy: 50.1%, Valid: 47.6%
# Learning Rate: 0.04181
# Epoch  175, Train Loss: 1.493, Train Accuracy: 50.1%, Valid: 47.7%
# Learning Rate: 0.04181
# Epoch  176, Train Loss: 1.492, Train Accuracy: 50.1%, Valid: 47.7%
# Learning Rate: 0.04181
# Epoch  177, Train Loss: 1.491, Train Accuracy: 50.1%, Valid: 47.7%
# Learning Rate: 0.04181
# Epoch  178, Train Loss: 1.491, Train Accuracy: 50.2%, Valid: 47.7%
# Learning Rate: 0.04181
# Epoch  179, Train Loss: 1.490, Train Accuracy: 50.2%, Valid: 47.8%
# Learning Rate: 0.04181
# Epoch  180, Train Loss: 1.489, Train Accuracy: 50.2%, Valid: 47.8%
# Learning Rate: 0.03972
# Epoch  181, Train Loss: 1.488, Train Accuracy: 50.2%, Valid: 47.9%
# Learning Rate: 0.03972
# Epoch  182, Train Loss: 1.488, Train Accuracy: 50.3%, Valid: 47.9%
# Learning Rate: 0.03972
# Epoch  183, Train Loss: 1.487, Train Accuracy: 50.3%, Valid: 48.1%
# Learning Rate: 0.03972
# Epoch  184, Train Loss: 1.486, Train Accuracy: 50.3%, Valid: 48.4%
# Learning Rate: 0.03972
# Epoch  185, Train Loss: 1.486, Train Accuracy: 50.3%, Valid: 48.4%
# Learning Rate: 0.03972
# Epoch  186, Train Loss: 1.485, Train Accuracy: 50.4%, Valid: 48.5%
# Learning Rate: 0.03972
# Epoch  187, Train Loss: 1.484, Train Accuracy: 50.4%, Valid: 48.5%
# Learning Rate: 0.03972
# Epoch  188, Train Loss: 1.484, Train Accuracy: 50.4%, Valid: 48.5%
# Learning Rate: 0.03972
# Epoch  189, Train Loss: 1.483, Train Accuracy: 50.4%, Valid: 48.5%
# Learning Rate: 0.03972
# Epoch  190, Train Loss: 1.482, Train Accuracy: 50.5%, Valid: 48.4%
# Learning Rate: 0.03774
# Epoch  191, Train Loss: 1.482, Train Accuracy: 50.5%, Valid: 48.4%
# Learning Rate: 0.03774
# Epoch  192, Train Loss: 1.481, Train Accuracy: 50.5%, Valid: 48.4%
# Learning Rate: 0.03774
# Epoch  193, Train Loss: 1.480, Train Accuracy: 50.5%, Valid: 48.4%
# Learning Rate: 0.03774
# Epoch  194, Train Loss: 1.480, Train Accuracy: 50.5%, Valid: 48.5%
# Learning Rate: 0.03774
# Epoch  195, Train Loss: 1.479, Train Accuracy: 50.6%, Valid: 48.4%
# Learning Rate: 0.03774
# Epoch  196, Train Loss: 1.479, Train Accuracy: 50.6%, Valid: 48.3%
# Learning Rate: 0.03774
# Epoch  197, Train Loss: 1.478, Train Accuracy: 50.6%, Valid: 48.3%
# Learning Rate: 0.03774
# Epoch  198, Train Loss: 1.477, Train Accuracy: 50.7%, Valid: 48.3%
# Learning Rate: 0.03774
# Epoch  199, Train Loss: 1.477, Train Accuracy: 50.7%, Valid: 48.2%
# Learning Rate: 0.03774
# Epoch  200, Train Loss: 1.476, Train Accuracy: 50.7%, Valid: 48.2%
# Learning Rate: 0.03585
# Epoch  201, Train Loss: 1.475, Train Accuracy: 50.7%, Valid: 48.2%
# Learning Rate: 0.03585
# Epoch  202, Train Loss: 1.475, Train Accuracy: 50.8%, Valid: 48.2%
# Learning Rate: 0.03585
# Epoch  203, Train Loss: 1.474, Train Accuracy: 50.8%, Valid: 48.2%
# Learning Rate: 0.03585
# Epoch  204, Train Loss: 1.474, Train Accuracy: 50.8%, Valid: 48.3%
# Learning Rate: 0.03585
# Epoch  205, Train Loss: 1.473, Train Accuracy: 50.8%, Valid: 48.3%
# Learning Rate: 0.03585
# Epoch  206, Train Loss: 1.473, Train Accuracy: 50.8%, Valid: 48.4%
# Learning Rate: 0.03585
# Epoch  207, Train Loss: 1.472, Train Accuracy: 50.9%, Valid: 48.5%
# Learning Rate: 0.03585
# Epoch  208, Train Loss: 1.471, Train Accuracy: 50.9%, Valid: 48.5%
# Learning Rate: 0.03585
# Epoch  209, Train Loss: 1.471, Train Accuracy: 50.9%, Valid: 48.7%
# Learning Rate: 0.03585
# Epoch  210, Train Loss: 1.470, Train Accuracy: 50.9%, Valid: 48.6%
# Learning Rate: 0.03406
# Epoch  211, Train Loss: 1.470, Train Accuracy: 50.9%, Valid: 48.6%
# Learning Rate: 0.03406
# Epoch  212, Train Loss: 1.469, Train Accuracy: 51.0%, Valid: 48.6%
# Learning Rate: 0.03406
# Epoch  213, Train Loss: 1.469, Train Accuracy: 51.0%, Valid: 48.6%
# Learning Rate: 0.03406
# Epoch  214, Train Loss: 1.468, Train Accuracy: 51.0%, Valid: 48.6%
# Learning Rate: 0.03406
# Epoch  215, Train Loss: 1.467, Train Accuracy: 51.0%, Valid: 48.5%
# Learning Rate: 0.03406
# Epoch  216, Train Loss: 1.467, Train Accuracy: 51.1%, Valid: 48.5%
# Learning Rate: 0.03406
# Epoch  217, Train Loss: 1.466, Train Accuracy: 51.1%, Valid: 48.5%
# Learning Rate: 0.03406
# Epoch  218, Train Loss: 1.466, Train Accuracy: 51.1%, Valid: 48.6%
# Learning Rate: 0.03406
# Epoch  219, Train Loss: 1.465, Train Accuracy: 51.1%, Valid: 48.6%
# Learning Rate: 0.03406
# Epoch  220, Train Loss: 1.465, Train Accuracy: 51.1%, Valid: 48.5%
# Learning Rate: 0.03235
# Epoch  221, Train Loss: 1.464, Train Accuracy: 51.2%, Valid: 48.6%
# Learning Rate: 0.03235
# Epoch  222, Train Loss: 1.464, Train Accuracy: 51.2%, Valid: 48.6%
# Learning Rate: 0.03235
# Epoch  223, Train Loss: 1.463, Train Accuracy: 51.2%, Valid: 48.5%
# Learning Rate: 0.03235
# Epoch  224, Train Loss: 1.463, Train Accuracy: 51.2%, Valid: 48.5%
# Learning Rate: 0.03235
# Epoch  225, Train Loss: 1.462, Train Accuracy: 51.2%, Valid: 48.5%
# Learning Rate: 0.03235
# Epoch  226, Train Loss: 1.462, Train Accuracy: 51.2%, Valid: 48.5%
# Learning Rate: 0.03235
# Epoch  227, Train Loss: 1.461, Train Accuracy: 51.2%, Valid: 48.5%
# Learning Rate: 0.03235
# Epoch  228, Train Loss: 1.461, Train Accuracy: 51.3%, Valid: 48.4%
# Learning Rate: 0.03235
# Epoch  229, Train Loss: 1.460, Train Accuracy: 51.3%, Valid: 48.5%
# Learning Rate: 0.03235
# Epoch  230, Train Loss: 1.460, Train Accuracy: 51.3%, Valid: 48.5%
# Learning Rate: 0.03074
# Epoch  231, Train Loss: 1.459, Train Accuracy: 51.3%, Valid: 48.4%
# Learning Rate: 0.03074
# Epoch  232, Train Loss: 1.459, Train Accuracy: 51.3%, Valid: 48.4%
# Learning Rate: 0.03074
# Epoch  233, Train Loss: 1.458, Train Accuracy: 51.4%, Valid: 48.5%
# Learning Rate: 0.03074
# Epoch  234, Train Loss: 1.458, Train Accuracy: 51.4%, Valid: 48.5%
# Learning Rate: 0.03074
# Epoch  235, Train Loss: 1.457, Train Accuracy: 51.4%, Valid: 48.6%
# Learning Rate: 0.03074
# Epoch  236, Train Loss: 1.457, Train Accuracy: 51.4%, Valid: 48.6%
# Learning Rate: 0.03074
# Epoch  237, Train Loss: 1.456, Train Accuracy: 51.5%, Valid: 48.6%
# Learning Rate: 0.03074

# %% [markdown]
# ## Train using Adam
# Next we will train the same model using the Adam optimizer. You should take the above code for SGD and modify it to use Adam instead. For implementation details, see the lecture slides. The original paper that introduced Adam is also a good reference, and contains suggestions for default values: https://arxiv.org/pdf/1412.6980.pdf

# %%
# Hyperparameters
input_size = 32 * 32 * 3
num_layers = 3
hidden_size = 120
hidden_sizes = [hidden_size] * (num_layers - 1)
num_classes = 10
epochs = 400
batch_size = 200
learning_rate = 1e-2
learning_rate_decay = 0.95
regularization = 0.0001
beta1 = 0.9
beta2 = 0.999
eps = 1e-8


# Initialize a new neural network model
net = NeuralNetwork(input_size, hidden_sizes, num_classes, num_layers,isadam = True)

# Variables to store performance for each epoch
train_loss_ADAM = np.zeros(epochs)
train_accuracy_ADAM = np.zeros(epochs)
validation_ADAM = np.zeros(epochs)

# For each epoch...
for epoch in range(epochs):
    # Training
    # For each mini-batch...
    #rate = learning_rate
    rate = learning_rate*(learning_rate_decay ** (epoch//10))
    print("Learning Rate: %.5f" %(rate))
    batch_index= np.random.choice(TRAIN_IMAGES, batch_size, replace=False)
    X_batch = X_train[batch_index]
    y_batch = y_train[batch_index]
    # Run the forward pass of the model to get a prediction and compute the accuracy
    # Run the backward pass of the model to update the weights and compute the loss
    train_loss_ADAM[epoch] = net.backward(X_train,y_train, rate, regularization)
    train_accuracy_ADAM[epoch] = (np.argmax(net.outputs["L1"+ str(num_layers)],axis = 1) == y_train).mean()
    # Validation
    # No need to run the backward pass here, just run the forward pass to compute accuracy
    validation_ADAM[epoch] = (np.argmax(net.forward(X_val),axis = 1) == y_val).mean()
    print("Epoch %4d, Train Loss: %4.3f, Train Accuracy: %3.1f%%, Valid: %3.1f%%" %(epoch + 1, train_loss_ADAM[epoch], train_accuracy_ADAM[epoch] * 100, validation_ADAM[epoch] * 100))
# Out:
# Learning Rate: 0.01000
# Epoch    1, Train Loss: 2.381, Train Accuracy: 10.3%, Valid: 21.6%
# Learning Rate: 0.01000
# Epoch    2, Train Loss: 7.993, Train Accuracy: 19.4%, Valid: 15.8%
# Learning Rate: 0.01000
# Epoch    3, Train Loss: 8.515, Train Accuracy: 17.2%, Valid: 21.6%
# Learning Rate: 0.01000
# Epoch    4, Train Loss: 7.830, Train Accuracy: 22.8%, Valid: 19.0%
# Learning Rate: 0.01000
# Epoch    5, Train Loss: 7.082, Train Accuracy: 19.2%, Valid: 20.5%
# Learning Rate: 0.01000
# Epoch    6, Train Loss: 6.805, Train Accuracy: 17.7%, Valid: 19.4%
# Learning Rate: 0.01000
# Epoch    7, Train Loss: 5.947, Train Accuracy: 18.0%, Valid: 25.8%
# Learning Rate: 0.01000
# Epoch    8, Train Loss: 5.147, Train Accuracy: 23.8%, Valid: 24.0%
# Learning Rate: 0.01000
# Epoch    9, Train Loss: 4.662, Train Accuracy: 23.6%, Valid: 22.7%
# Learning Rate: 0.01000
# Epoch   10, Train Loss: 3.996, Train Accuracy: 22.8%, Valid: 22.3%
# Learning Rate: 0.00950
# Epoch   11, Train Loss: 3.594, Train Accuracy: 21.7%, Valid: 21.6%
# Learning Rate: 0.00950
# Epoch   12, Train Loss: 3.643, Train Accuracy: 21.0%, Valid: 21.6%
# Learning Rate: 0.00950
# Epoch   13, Train Loss: 3.461, Train Accuracy: 20.8%, Valid: 23.0%
# Learning Rate: 0.00950
# Epoch   14, Train Loss: 2.639, Train Accuracy: 22.3%, Valid: 23.8%
# Learning Rate: 0.00950
# Epoch   15, Train Loss: 2.637, Train Accuracy: 23.8%, Valid: 24.7%
# Learning Rate: 0.00950
# Epoch   16, Train Loss: 2.675, Train Accuracy: 23.1%, Valid: 23.6%
# Learning Rate: 0.00950
# Epoch   17, Train Loss: 2.378, Train Accuracy: 22.5%, Valid: 24.5%
# Learning Rate: 0.00950
# Epoch   18, Train Loss: 2.221, Train Accuracy: 23.3%, Valid: 24.6%
# Learning Rate: 0.00950
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-101-38dd0debf6d5> in <module>()
#      35     # Run the forward pass of the model to get a prediction and compute the accuracy
#      36     # Run the backward pass of the model to update the weights and compute the loss
# ---> 37     train_loss_ADAM[epoch] = net.backward(X_train,y_train, rate, regularization)
#      38     train_accuracy_ADAM[epoch] = (np.argmax(net.outputs["L1"+ str(num_layers)],axis = 1) == y_train).mean()
#      39     # Validation
#
# C:\Users\BillY\Documents\AI\CS-498-Introduction-to-Deep-Learning\assignment2\models\neural_net.py in backward(self, X, y, lr, reg)
#     164         dz1 = softmax_matrix / N
#     165         for i in range(self.num_layers, 0, -1):
# --> 166             gw = np.dot(self.outputs["L2" + str(i - 1)].T, dz1) + 2 * reg * self.params["W" + str(i)].x
#     167             gb = np.sum(dz1, axis=0)
#     168             dz1 = (dz1.dot(self.params["W" + str(i)].x.T)) * (self.outputs["L1" + str(i - 1)] > 0)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Graph loss and train/val accuracies
#
# Examining the loss graph along with the train and val accuracy graphs should help you gain some intuition for the hyperparameters you should try in the hyperparameter tuning below. It should also help with debugging any issues you might have with your network.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 2, 1)
plt.plot(train_loss_SGD)
plt.title('Loss history_SGD')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 2, 2)
plt.plot(train_loss_ADAM)
plt.title('Loss history_ADAM')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(train_accuracy_SGD, label='train')
plt.plot(validation_SGD, label='val')
plt.title('Classification accuracy history SGD')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

plt.subplot(2, 2, 4)
plt.plot(train_accuracy_ADAM, label='train')
plt.plot(validation_ADAM, label='val')
plt.title('Classification accuracy history ADAM')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Hyperparameter tuning
#
# Once you have successfully trained a network you can tune your hyparameters to increase your accuracy.
#
# Based on the graphs of the loss function above you should be able to develop some intuition about what hyperparameter adjustments may be necessary. A very noisy loss implies that the learning rate might be too high, while a linearly decreasing loss would suggest that the learning rate may be too low. A large gap between training and validation accuracy would suggest overfitting due to large model without much regularization. No gap between training and validation accuracy would indicate low model capacity.
#
# You will compare networks of two and three layers using the different optimization methods you implemented.
#
# The different hyperparameters you can experiment with are:
# - **Batch size**: We recommend you leave this at 200 initially which is the batch size we used.
# - **Number of iterations**: You can gain an intuition for how many iterations to run by checking when the validation accuracy plateaus in your train/val accuracy graph.
# - **Initialization** Weight initialization is very important for neural networks. We used the initialization `W = np.random.randn(n) / sqrt(n)` where `n` is the input dimension for layer corresponding to `W`. We recommend you stick with the given initializations, but you may explore modifying these. Typical initialization practices: http://cs231n.github.io/neural-networks-2/#init
# - **Learning rate**: Generally from around 1e-4 to 1e-1 is a good range to explore according to our implementation.
# - **Learning rate decay**: We recommend a 0.95 decay to start.
# - **Hidden layer size**: You should explore up to around 120 units per layer. For three-layer network, we fixed the two hidden layers to be the same size when obtaining the target numbers. However, you may experiment with having different size hidden layers.
# - **Regularization coefficient**: We recommend trying values in the range 0 to 0.1.
#
# Hints:
# - After getting a sense of the parameters by trying a few values yourself, you will likely want to write a few for-loops to traverse over a set of hyperparameters.
# - If you find that your train loss is decreasing, but your train and val accuracy start to decrease rather than increase, your model likely started minimizing the regularization term. To prevent this you will need to decrease the regularization coefficient.

# %% [markdown]
# ## Run on the test set
# When you are done experimenting, you should evaluate your final trained networks on the test set.

# %%
#best_2layer_sgd_prediction = np.argmax(net.forward(X_test),axis = 1)
best_3layer_sgd_prediction = np.argmax(net.forward(X_test),axis = 1)
#best_2layer_adam_prediction = np.argmax(net.forward(X_test),axis = 1) 
# best_3layer_adam_prediction = np.argmax(net.forward(X_test),axis = 1)

# %% [markdown]
# ## Kaggle output
#
# Once you are satisfied with your solution and test accuracy, output a file to submit your test set predictions to the Kaggle for Assignment 2 Neural Network. Use the following code to do so:

# %%
#output_submission_csv('kaggle/nn_2layer_sgd_submission.csv', best_2layer_sgd_prediction)
output_submission_csv('kaggle/nn_3layer_sgd_submission.csv', best_3layer_sgd_prediction)
#output_submission_csv('kaggle/nn_2layer_adam_submission.csv', best_2layer_adam_prediction)
# output_submission_csv('kaggle/nn_3layer_adam_submission.csv', best_3layer_adam_prediction)

# %% [markdown]
# ## Compare SGD and Adam
# Create graphs to compare training loss and validation accuracy between SGD and Adam. The code is similar to the above code, but instead of comparing train and validation, we are comparing SGD and Adam.

# %%
# TODO: implement me
plt.subplot(2, 1, 2)
plt.plot(train_loss_SGD, label='SGD')
plt.plot(train_loss_ADAM_, label='ADAM')
plt.title('Training Loss history')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.subplot(2, 1, 2)
plt.plot(validation_SGD, label='SGD')
plt.plot(validation_ADAM, label='ADAM')
plt.title('Validation Accuracy')
plt.xlabel('Iterations')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
